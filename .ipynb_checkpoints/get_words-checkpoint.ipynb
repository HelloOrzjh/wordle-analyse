# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

# %%
valid_guesses_csv = pd.read_csv("valid_guesses.csv")
valid_solutions_csv = pd.read_csv("valid_solutions.csv")
valid_guesses_csv = valid_guesses_csv.merge(valid_solutions_csv, how='outer')

# %%
data = pd.read_excel("COCA60000FULL.xlsx")
data["word"] = data["word"].str.replace(' ', '')

data
# Out:
#        RANK #  PoS       word     TOTAL   SPOKEN  FICTION  MAGAZINE  \
# 0           1   A         the  23782115  4183469  4531786   4875815
# 1           2   V          be  16711569  4873288  3173845   2989059
# 2           3   C         and  11654439  2347151  2188166   2388111
# 3           4   I          of  11155504  1857279  1630728   2329089
# 4           5   A           a  10999596  2110287  2125067   2496150
# ...       ...  ...        ...       ...      ...      ...       ...
# 60018   60020   N    hecatomb        20        0        2         2
# 60019   60021   N    sideslip        19        0       16         3
# 60020   60022   N      gaoler        23        0        1         0
# 60021   60023   N   carcinoid        21        0        0         0
# 60022   60024   N       tonus        21        0        1         2
#
#        NEWSPAPER  ACADEMIC
# 0        4646517   5544528
# 1        2926800   2748577
# 2        2130798   2600213
# 3        2050072   3288336
# 4        2331699   1936393
# ...          ...       ...
# 60018          0        16
# 60019          0         0
# 60020          0        22
# 60021          0        21
# 60022          0        18
#
# [60023 rows x 9 columns]

# %%
data_selected = data[data["word"].str.len() == 5]
data_selected = data_selected.sort_values(by="TOTAL", axis=0, ascending=True)
data_selected["weight"] = data_selected["TOTAL"] / data_selected["TOTAL"].sum()
data_selected
# Out:
#        RANK #  PoS   word    TOTAL  SPOKEN  FICTION  MAGAZINE  NEWSPAPER  \
# 57873   57875   J   unhip       18       0        7         4          6
# 59267   59269   R   roily       19       0       11         7          0
# 58747   58749   J   topsy       19       4       10         2          1
# 58806   58808   N   shoat       19       0       14         2          2
# 58818   58820   J   homed       19       0       10         4          0
# ...       ...  ...    ...      ...     ...      ...       ...        ...
# 55         56   V   think   838695  423892   193081     88312      93525
# 52         53   E   there   846483  301556   155571    135904     139865
# 45         46   I   about   952604  328762   178533    163092     163636
# 40         41   V   would  1000182  251284   257792    166384     178690
# 35         36   A   their  1170105  184917   176141    250636     232098
#
#        ACADEMIC        weight
# 57873         1  4.164350e-07
# 59267         1  4.395703e-07
# 58747         2  4.395703e-07
# 58806         1  4.395703e-07
# 58818         5  4.395703e-07
# ...         ...           ...
# 55        39885  1.940344e-02
# 52       113587  1.958362e-02
# 45       118581  2.203876e-02
# 40       146032  2.313949e-02
# 35       326313  2.707070e-02
#
# [4154 rows x 10 columns]

# %%
valid_guesses_inner = valid_guesses_csv.merge(data_selected, how='inner', on='word')
valid_guesses_inner = valid_guesses_inner[ valid_guesses_inner["weight"] >= 0.000000001 ]
valid_guesses_inner = valid_guesses_inner.reset_index()
valid_guesses_inner
# Out:
#       index   word  RANK #  PoS   TOTAL  SPOKEN  FICTION  MAGAZINE  NEWSPAPER  \
# 0         0  abash   49621   V       32       7       12         6          3
# 1         1  abaya   43717   N       69      12       12        14         24
# 2         2  ackee   58672   N       29       0       10        13          3
# 3         3  actin   31873   N      148       8       45        32          0
# 4         4  added    4592   J     6047     449      462      2121       1734
# ...     ...    ...     ...  ...     ...     ...      ...       ...        ...
# 3946   3946  young     234   J   173683   31095    42319     34792      36717
# 3947   3947  youth    1401   N    31288    2434     3196      4907       7636
# 3948   3948  zebra   14397   N     1148     110      242       445        136
# 3949   3949  zesty   28061   J      211       6       11       129         63
# 3950   3950  zonal   41500   J       66       1        1        17          2
#
#       ACADEMIC        weight
# 0            4  7.403288e-07
# 1            7  1.596334e-06
# 2            3  6.709230e-07
# 3           63  3.424021e-06
# 4         1281  1.398990e-04
# ...        ...           ...
# 3946     28760  4.018204e-03
# 3947     13115  7.238565e-04
# 3948       215  2.655930e-05
# 3949         2  4.881543e-06
# 3950        45  1.526928e-06
#
# [3951 rows x 11 columns]

# %%
valid_solutions_inner = valid_solutions_csv.merge(data_selected, how='inner', on='word')
valid_solutions_inner = valid_solutions_inner[ valid_solutions_inner["weight"] >= 0.0004 ]
valid_solutions_inner = valid_solutions_inner.reset_index()
valid_solutions_inner
# Out:
#      index   word  RANK #  PoS    TOTAL  SPOKEN  FICTION  MAGAZINE  NEWSPAPER  \
# 0        8  about     179   R    226187   56650    33118     57435      54485
# 1        9  about      46   I    952604  328762   178533    163092     163636
# 2       11  above    1595   R     25231     821     3498     10410       2163
# 3       12  above     894   I     47550    3965    16189     12222       6849
# 4       14  abuse    1545   N     26768    6019      764      5086       5387
# ..     ...    ...     ...  ...      ...     ...      ...       ...        ...
# 398   2960  would      41   V   1000182  251284   257792    166384     178690
# 399   2973  write     228   V    176548   35949    27278     37680      35245
# 400   2977  wrong     655   J     63810   21611    17297     10356       9579
# 401   2984  young     234   J    173683   31095    42319     34792      36717
# 402   2985  youth    1401   N     31288    2434     3196      4907       7636
#
#      ACADEMIC    weight
# 0       24499  0.005233
# 1      118581  0.022039
# 2        8339  0.000584
# 3        8325  0.001100
# 4        9512  0.000619
# ..        ...       ...
# 398    146032  0.023139
# 399     40396  0.004084
# 400      4967  0.001476
# 401     28760  0.004018
# 402     13115  0.000724
#
# [403 rows x 11 columns]

# %%
valid_guesses = valid_guesses_inner["word"].tolist()
valid_solutions = valid_solutions_inner["word"].tolist()

valid_guesses.append("eerie")
valid_solutions.append("eerie")

valid_guesses = list( set(valid_guesses) )
valid_solutions = list( set(valid_solutions) )
valid_guesses = sorted(valid_guesses)
valid_solutions = sorted(valid_solutions)

valid_guesses_cnt = len(valid_guesses)
valid_solutions_cnt = len(valid_solutions)

# print(valid_guesses)
# print(valid_solutions)
# print(valid_guesses_cnt)
# print(valid_solutions_cnt)
# Out:
# ['aback', 'abase', 'abash', 'abate', 'abaya', 'abbot', 'abhor', 'abide', 'abode', 'abort', 'about', 'above', 'abuse', 'abyss', 'ackee', 'acorn', 'acrid', 'actin', 'actor', 'acute', 'adage', 'adapt', 'added', 'adder', 'addle', 'adept', 'adieu', 'adios', 'adman', 'admin', 'admit', 'adobe', 'adobo', 'adopt', 'adore', 'adorn', 'adult', 'aegis', 'aerie', 'affix', 'afire', 'afoot', 'afore', 'after', 'again', 'agape', 'agave', 'agent', 'aggro', 'agile', 'aging', 'aglow', 'agony', 'agora', 'agree', 'ahead', 'ahold', 'aided', 'aioli', 'aired', 'aisle', 'alarm', 'album', 'alder', 'alert', 'algae', 'algal', 'alias', 'alibi', 'alien', 'align', 'alike', 'alive', 'alkyd', 'allay', 'alley', 'allot', 'allow', 'alloy', 'aloft', 'alone', 'along', 'aloof', 'aloud', 'alpha', 'altar', 'alter', 'amass', 'amaze', 'amber', 'ambit', 'amble', 'amend', 'amine', 'amino', 'amiss', 'amity', 'amnio', 'among', 'amour', 'ample', 'amply', 'amuse', 'ancho', 'angel', 'anger', 'angle', 'anglo', 'angry', 'angst', 'anima', 'anime', 'anion', 'anise', 'ankle', 'annal', 'annex', 'annoy', 'annul', 'anode', 'anole', 'antic', 'antsy', 'anvil', 'aorta', 'apace', 'apart', 'aphid', 'apnea', 'apple', 'apply', 'apron', 'aptly', 'ardor', 'areal', 'arena', 'argon', 'argot', 'argue', 'arise', 'armed', 'armor', 'aroma', 'array', 'arrow', 'arson', 'artsy', 'ashen', 'aside', 'askew', 'aspic', 'assay', 'asset', 'aster', 'astir', 'atman', 'atoll', 'atone', 'attar', 'attic', 'audio', 'audit', 'auger', 'aught', 'augur', 'aunty', 'aural', 'avail', 'avert', 'avian', 'avoid', 'await', 'awake', 'award', 'aware', 'awash', 'awful', 'axial', 'axiom', 'axion', 'azure', 'bacon', 'badge', 'badly', 'bagel', 'baggy', 'bairn', 'baize', 'baked', 'baker', 'baled', 'balky', 'balmy', 'balsa', 'banal', 'bandy', 'banjo', 'bared', 'barge', 'basal', 'basic', 'basil', 'basin', 'basis', 'basso', 'baste', 'batch', 'bated', 'bathe', 'batik', 'batty', 'bawdy', 'bazar', 'beach', 'beady', 'beaky', 'beamy', 'beard', 'beast', 'beaut', 'bebop', 'beefy', 'beery', 'befit', 'beget', 'begin', 'begum', 'beige', 'being', 'belay', 'belch', 'belie', 'belly', 'below', 'bench', 'benne', 'beret', 'berry', 'berth', 'beset', 'betel', 'bevel', 'bezel', 'bible', 'bidet', 'bight', 'bigot', 'biker', 'bilge', 'bimbo', 'binge', 'bingo', 'biome', 'biota', 'biped', 'bipod', 'birch', 'birth', 'bison', 'bitch', 'biter', 'bitty', 'black', 'blade', 'blahs', 'blame', 'bland', 'blank', 'blare', 'blase', 'blast', 'blaze', 'bleak', 'bleat', 'bleed', 'bleep', 'blend', 'bless', 'blimp', 'blind', 'bling', 'blini', 'blink', 'bliss', 'blitz', 'bloat', 'block', 'bloke', 'blond', 'blood', 'bloom', 'bloop', 'blown', 'blued', 'bluff', 'blunt', 'blurb', 'blurt', 'blush', 'board', 'boast', 'bocce', 'boeuf', 'boffo', 'bogey', 'boggy', 'bogus', 'bolus', 'boned', 'boner', 'boney', 'bonny', 'bonus', 'booby', 'boost', 'booth', 'booty', 'booze', 'boozy', 'borax', 'bored', 'borer', 'boric', 'boron', 'bosom', 'boson', 'bossy', 'bosun', 'botch', 'bough', 'boule', 'bound', 'bowed', 'bowel', 'boxed', 'boxer', 'boyar', 'brace', 'bract', 'braid', 'brain', 'brake', 'brand', 'brane', 'brash', 'brass', 'brave', 'brawl', 'brawn', 'braze', 'bread', 'break', 'bream', 'breed', 'briar', 'bribe', 'brick', 'bride', 'brief', 'brier', 'brine', 'bring', 'brink', 'briny', 'brisk', 'broad', 'broil', 'broke', 'bronc', 'brood', 'brook', 'broom', 'broth', 'brown', 'bruit', 'brunt', 'brush', 'brute', 'bucko', 'buddy', 'budge', 'buggy', 'bugle', 'build', 'bulge', 'bulky', 'bully', 'bumpy', 'bunch', 'bunco', 'bunny', 'burin', 'burka', 'burly', 'burnt', 'burro', 'burst', 'bushy', 'busty', 'butch', 'buxom', 'buyer', 'buzzy', 'bylaw', 'byway', 'cabal', 'cabby', 'caber', 'cabin', 'cable', 'cacao', 'cache', 'caddy', 'cadet', 'cadge', 'cadre', 'caged', 'cagey', 'cairn', 'calla', 'calve', 'calyx', 'camel', 'cameo', 'campy', 'canal', 'candy', 'caned', 'canid', 'canna', 'canny', 'canoe', 'canon', 'canst', 'canto', 'caped', 'caper', 'capon', 'carat', 'cargo', 'carny', 'carob', 'carol', 'carom', 'ca ...
# ['about', 'above', 'abuse', 'actor', 'admit', 'adopt', 'adult', 'after', 'again', 'agent', 'agree', 'ahead', 'album', 'alive', 'allow', 'alone', 'along', 'among', 'angry', 'apart', 'apple', 'apply', 'argue', 'aside', 'asset', 'avoid', 'award', 'aware', 'basic', 'basis', 'beach', 'begin', 'being', 'below', 'birth', 'black', 'blame', 'block', 'blood', 'board', 'brain', 'bread', 'break', 'bring', 'broad', 'brown', 'build', 'cable', 'carry', 'catch', 'cause', 'chain', 'chair', 'cheap', 'check', 'chest', 'chief', 'child', 'civil', 'claim', 'class', 'clean', 'clear', 'climb', 'close', 'cloud', 'coach', 'coast', 'color', 'could', 'count', 'court', 'cover', 'crazy', 'cream', 'crime', 'cross', 'crowd', 'daily', 'dance', 'death', 'doubt', 'dozen', 'dream', 'dress', 'drink', 'drive', 'early', 'eerie', 'eight', 'empty', 'enemy', 'enjoy', 'enter', 'equal', 'error', 'event', 'every', 'exist', 'extra', 'faith', 'fewer', 'field', 'fight', 'final', 'first', 'floor', 'focus', 'force', 'forth', 'frame', 'fresh', 'front', 'fruit', 'fully', 'funny', 'glass', 'grade', 'grand', 'grant', 'grass', 'great', 'green', 'group', 'guard', 'guess', 'guest', 'guide', 'happy', 'heart', 'heavy', 'hello', 'honor', 'horse', 'hotel', 'house', 'human', 'image', 'issue', 'judge', 'juice', 'knock', 'labor', 'large', 'later', 'laugh', 'layer', 'learn', 'least', 'leave', 'legal', 'level', 'light', 'limit', 'local', 'lower', 'lucky', 'lunch', 'major', 'marry', 'match', 'maybe', 'mayor', 'media', 'metal', 'might', 'model', 'money', 'month', 'moral', 'mouth', 'movie', 'music', 'never', 'night', 'noise', 'north', 'novel', 'nurse', 'occur', 'ocean', 'offer', 'often', 'order', 'other', 'ought', 'owner', 'paint', 'panel', 'paper', 'party', 'peace', 'phone', 'piece', 'pilot', 'place', 'plane', 'plant', 'plate', 'point', 'pound', 'power', 'press', 'price', 'prime', 'proud', 'prove', 'quick', 'quiet', 'quite', 'radio', 'raise', 'range', 'reach', 'ready', 'refer', 'reply', 'right', 'river', 'route', 'rural', 'sauce', 'scale', 'scene', 'score', 'sense', 'serve', 'seven', 'shake', 'shape', 'share', 'sharp', 'sheet', 'shift', 'shirt', 'shoot', 'short', 'shout', 'sight', 'since', 'skill', 'sleep', 'slide', 'small', 'smart', 'smile', 'solid', 'solve', 'sorry', 'sound', 'south', 'space', 'speak', 'speed', 'spend', 'sport', 'staff', 'stage', 'stand', 'stare', 'start', 'state', 'steal', 'steel', 'stick', 'still', 'stock', 'stone', 'store', 'storm', 'story', 'study', 'stuff', 'style', 'sugar', 'sweet', 'table', 'taste', 'teach', 'thank', 'their', 'theme', 'there', 'these', 'thick', 'thing', 'think', 'third', 'those', 'three', 'throw', 'title', 'today', 'tooth', 'topic', 'total', 'touch', 'tough', 'track', 'trade', 'trail', 'train', 'treat', 'trend', 'trial', 'troop', 'truck', 'truly', 'trust', 'truth', 'twice', 'uncle', 'under', 'union', 'until', 'upper', 'urban', 'value', 'video', 'visit', 'voice', 'voter', 'waste', 'watch', 'water', 'wheel', 'where', 'which', 'while', 'white', 'whole', 'whose', 'woman', 'world', 'worry', 'worth', 'would', 'write', 'wrong', 'young', 'youth']
# 2992
# 341

# %%
valid_guesses_csv = pd.DataFrame(valid_guesses, columns=["word"])
valid_guesses_csv.to_csv("valid_guesses_words.csv")
valid_solutions_csv = pd.DataFrame(valid_solutions, columns=["word"])
valid_solutions_csv.to_csv("valid_solutions_words.csv")

# %%
data = pd.read_excel("COCA60000FULL.xlsx")
data["word"] = data["word"].str.replace(' ', '')

data_selected = data[data["word"].str.len() == 5]
word_frequency = data_selected.sort_values(by="TOTAL", axis=0, ascending=True)
word_frequency
# Out:
#        RANK #  PoS   word    TOTAL  SPOKEN  FICTION  MAGAZINE  NEWSPAPER  \
# 57873   57875   J   unhip       18       0        7         4          6
# 59267   59269   R   roily       19       0       11         7          0
# 58747   58749   J   topsy       19       4       10         2          1
# 58806   58808   N   shoat       19       0       14         2          2
# 58818   58820   J   homed       19       0       10         4          0
# ...       ...  ...    ...      ...     ...      ...       ...        ...
# 55         56   V   think   838695  423892   193081     88312      93525
# 52         53   E   there   846483  301556   155571    135904     139865
# 45         46   I   about   952604  328762   178533    163092     163636
# 40         41   V   would  1000182  251284   257792    166384     178690
# 35         36   A   their  1170105  184917   176141    250636     232098
#
#        ACADEMIC
# 57873         1
# 59267         1
# 58747         2
# 58806         1
# 58818         5
# ...         ...
# 55        39885
# 52       113587
# 45       118581
# 40       146032
# 35       326313
#
# [4154 rows x 9 columns]

# %%
word_frequency["frequency"] = word_frequency["TOTAL"] / word_frequency["TOTAL"].sum()
word_frequency
# Out:
#        RANK #  PoS   word    TOTAL  SPOKEN  FICTION  MAGAZINE  NEWSPAPER  \
# 57873   57875   J   unhip       18       0        7         4          6
# 59267   59269   R   roily       19       0       11         7          0
# 58747   58749   J   topsy       19       4       10         2          1
# 58806   58808   N   shoat       19       0       14         2          2
# 58818   58820   J   homed       19       0       10         4          0
# ...       ...  ...    ...      ...     ...      ...       ...        ...
# 55         56   V   think   838695  423892   193081     88312      93525
# 52         53   E   there   846483  301556   155571    135904     139865
# 45         46   I   about   952604  328762   178533    163092     163636
# 40         41   V   would  1000182  251284   257792    166384     178690
# 35         36   A   their  1170105  184917   176141    250636     232098
#
#        ACADEMIC     frequency
# 57873         1  4.164350e-07
# 59267         1  4.395703e-07
# 58747         2  4.395703e-07
# 58806         1  4.395703e-07
# 58818         5  4.395703e-07
# ...         ...           ...
# 55        39885  1.940344e-02
# 52       113587  1.958362e-02
# 45       118581  2.203876e-02
# 40       146032  2.313949e-02
# 35       326313  2.707070e-02
#
# [4154 rows x 10 columns]

# %%
# 状态列表与状态码相互转换
def status_transform2number(status=[0, 0, 0, 0, 0]):
    res = 0
    a = 1
    for i in status:
        res += a * i
        a = a * 3
    return res

def number_transform2status(number=0):
    res = []
    for i in range(5):
        res.append(number % 3)
        number //= 3
    return res

# 生成合法的状态排列
def generate_status():
    res = []
    for i in range(243):
        cur = []
        x = i
        for j in range(5):
            cur.append(x % 3)
            x //= 3
        res.append(cur)
        
    return res

# %%
# 对猜测答案与正确答案之间进行验证
# 状态0代表完全错误，1代表字母正确且位置错误，2代表字母和位置都正确
def validation(guess, solution):
    result = [0, 0, 0, 0, 0]
    guess_list = list(guess)
    solution_list = list(solution)
    solution_letter_remainder = []
    
    for i in range(5):
        if guess_list[i] == solution_list[i]:
            result[i] = 2
        else:
            solution_letter_remainder.append(solution_list[i])
    
    for i in range(5):
        if result[i] == 2:
            continue
        for ch in solution_letter_remainder:
            if guess[i] == ch:
                result[i] = 1
                solution_letter_remainder.remove(ch)
                break
    
    return result

print( validation("grape", "hello") )
print( validation("heart", "hello") )
print( validation("hello", "hello") )
# Out:
# [0, 0, 0, 0, 1]
# [2, 2, 0, 0, 0]
# [2, 2, 2, 2, 2]

# %%
# 在单词集中找出符合要求的所有单词
def get_legal_words(guess, status, valid_words):
    legal_words = []
    
    for word in valid_words:
        result = validation(guess, word)
        flag = True
        
        for i in range(5):
            if status[i] != result[i]:
                flag = False
                break
                
        if flag == True:
            legal_words.append(word)
    
    return legal_words


print( get_legal_words("hello", [2, 2, 0, 0, 0], valid_solutions) )
print( get_legal_words("hello", [2, 2, 0, 0, 1], valid_solutions) )
print( get_legal_words("hello", [2, 2, 0, 0, 1], valid_guesses) )
# Out:
# ['heart', 'heavy']
# []
# ['heron']

# %%
# 计算信息量（信息熵）
def Entropy(p):
    if p == 0 or p == 1:
        return 0.0
    return - p * np.log(p) - (1.0 - p) * np.log(1.0 - p)


# 统计单词集中符合要求的所有单词的数量
def get_legal_words_cnt(guess, status, valid_words):
    legal_words = get_legal_words(guess, status, valid_words)
    return len(legal_words)


# 统计单词集中符合要求的所有单词的信息量（信息熵）
def get_legal_words_entropy(guess, status, valid_words):
    if len(valid_words) == 0:
        return 0.0
    p = get_legal_words_cnt(guess, status, valid_words) / len(valid_words)
    
    if p == 0 or p == 1:
        return 0.0
    entropy = Entropy(p)
    
    return entropy

# print( get_legal_words_entropy("hello", [2, 2, 0, 0, 0]) )
# print( get_legal_words_entropy("hello", [0, 0, 0, 0, 1]) )


# 计算总信息量（信息熵）
def get_legal_words_total_entropy(guess, last_status, valid_words):
    total_status = generate_status()
    total_entropy = 0
    for status in total_status:
        total_entropy += get_legal_words_entropy(guess, status, valid_words)
    return total_entropy

# print( get_legal_words_total_entropy("hello") )


# 获取词汇频率
def get_word_frequency(guess):
    result = word_frequency[ word_frequency["word"] == guess ]
    weight = result["frequency"].tolist()
    res = sum(weight)
    
    # print(res)
    return res
    
print( get_word_frequency("hello") )
# Out:
# 0.0004243472410662262

# %%
guess_legal_words_data = []
guess_legal_words_metrics_data = []

for guess in valid_guesses[0:0]:
    total_entropy = 0
    word_frequency = get_word_frequency(guess)
    # print(guess)
    
    for number in range(243):
        legal_words = get_legal_words(guess, number_transform2status(number), valid_solutions)
        len_of_legal_words = len(legal_words)
        if len_of_legal_words == 0:
            continue
        guess_legal_words_data.append([guess, number, legal_words, len_of_legal_words])
        total_entropy += Entropy(len_of_legal_words / valid_solutions_cnt)
    
    guess_legal_words_metrics_data.append([guess, total_entropy, word_frequency])

# %%
guess_legal_words_data = pd.DataFrame(guess_legal_words_data, columns=["guess", "number", "legal_words", "len_of_legal_words"], dtype=int)
guess_legal_words_data.to_csv("guess_legal_words_data(valid_solutions).csv")
guess_legal_words_metrics_data = pd.DataFrame(guess_legal_words_metrics_data, columns=["guess", "total_entropy", "word_frequency"], dtype=float)
guess_legal_words_metrics_data.to_csv("guess_legal_words_metrics_data(valid_solutions).csv")

# %%
guess_legal_words_data = []
# guess_legal_words_metrics_data = []

for guess in valid_guesses:
    # total_entropy = 0
    # words_frequency = get_word_frequency(guess)
    print(guess)
    
    for number in range(243):
        legal_words = get_legal_words(guess, number_transform2status(number), valid_guesses)
        len_of_legal_words = len(legal_words)
        if len_of_legal_words == 0:
            continue
        guess_legal_words_data.append([guess, number, legal_words, len_of_legal_words])
        # total_entropy += Entropy(len_of_legal_words / valid_guesses_cnt)
    
    # guess_legal_words_metrics_data.append([guess, total_entropy, words_frequency])


guess_legal_words_data = pd.DataFrame(guess_legal_words_data, columns=["guess", "number", "legal_words", "len_of_legal_words"], dtype=int)
guess_legal_words_data.to_csv("problem2_model_guess_legal_words_data(valid_guesses).csv")
# guess_legal_words_metrics_data = pd.DataFrame(guess_legal_words_metrics_data, columns=["guess", "total_entropy", "words_frequency"], dtype=float)
# guess_legal_words_metrics_data.to_csv("problem2_model_guess_legal_words_metrics_data(valid_solutions).csv")
# Out:
# aback
# abase
# abash
# abate
# abaya
# abbot
# abhor
# abide
# abode
# abort
# about
# above
# abuse
# abyss
# ackee
# acorn
# acrid
# actin
# actor
# acute
# adage
# adapt
# added
# adder
# addle
# adept
# adieu
# adios
# adman
# admin
# admit
# adobe
# adobo
# adopt
# adore
# adorn
# adult
# aegis
# aerie
# affix
# afire
# afoot
# afore
# after
# again
# agape
# agave
# agent
# aggro
# agile
# aging
# aglow
# agony
# agora
# agree
# ahead
# ahold
# aided
# aioli
# aired
# aisle
# alarm
# album
# alder
# alert
# algae
# algal
# alias
# alibi
# alien
# align
# alike
# alive
# alkyd
# allay
# alley
# allot
# allow
# alloy
# aloft
# alone
# along
# aloof
# aloud
# alpha
# altar
# alter
# amass
# amaze
# amber
# ambit
# amble
# amend
# amine
# amino
# amiss
# amity
# amnio
# among
# amour
# ample
# amply
# amuse
# ancho
# angel
# anger
# angle
# anglo
# angry
# angst
# anima
# anime
# anion
# anise
# ankle
# annal
# annex
# annoy
# annul
# anode
# anole
# antic
# antsy
# anvil
# aorta
# apace
# apart
# aphid
# apnea
# apple
# apply
# apron
# aptly
# ardor
# areal
# arena
# argon
# argot
# argue
# arise
# armed
# armor
# aroma
# array
# arrow
# arson
# artsy
# ashen
# aside
# askew
# aspic
# assay
# asset
# aster
# astir
# atman
# atoll
# atone
# attar
# attic
# audio
# audit
# auger
# aught
# augur
# aunty
